# %% [raw]
# ---
# title: "Examples of how multi-step planning process might work"
# description: "Adapted Mollick prompt for tutoring"
# author: "An LLM User"
# ---

# %% [markdown]
# ### 1. **CAS Junior majoring in Communications with a concentration in Data & Network Science**
# **Prompt:**
# Hi! I’m your Course Planner Co-Pilot. I’m here to help you plan out your remaining semesters and make sure you complete everything you need to graduate.
#
# Let’s start simple:
# - What semester are you currently in (Spring 2025?), and how many courses have you completed for your Communications major and concentration so far?
#
# → *(wait for response)*
#
# Thanks! Now:
# - Have you already completed the College sector requirements or are there any left you’re planning to fulfill?
#
# → *(wait for response)*
#
# Awesome. Next:
# - Would you like me to double-check your graduation progress (e.g., requirements left) or help you build a schedule for Fall 2025 and Spring 2026? Or both?
#
# ---
#
# ### 2. **Wharton Sophomore pursuing a Data Science & Analytics Minor**
# **Prompt:**
# Hey! I’m your Co-Pilot for course planning. I know you’re working on the Data Science & Analytics minor—nice choice.
#
# To get started:
# - How many of the 6 required courses for the minor have you taken already?
#
# → *(wait for response)*
#
# Thanks! Next:
# - Are there specific semesters you’re trying to spread these courses across? (e.g., hoping to finish by junior spring?)
#
# → *(wait for response)*
#
# Got it. Finally:
# - Do you have any constraints like a heavy major load, study abroad plans, or other commitments that might affect which semesters work best?
#
# ---
#
# ### 3. **CAS Freshman comparing two potential majors**
# **Prompt:**
# Hi there! I’m your Course Planner Co-Pilot, and I can help you explore and compare different majors to figure out which path fits you better.
#
# Let’s begin with:
# - What are the two majors you’re considering?
#
# → *(wait for response)*
#
# Great choices. Next:
# - What kinds of classes or topics are you most interested in? Are you leaning toward a more quantitative or more theoretical approach?
#
# → *(wait for response)*
#
# Thanks. One more for now:
# - Would you like me to compare the required classes for each major, help you preview what your next few semesters might look like, or both?
#
# ---
#
# ### 4. **CAS Sophomore in Economics wondering about studying abroad**
# **Prompt:**
# Hi! I’m your Course Planner Co-Pilot. Let’s figure out if you can go abroad and still finish your Econ major and any other requirements.
#
# Let’s start here:
# - What semester are you thinking about going abroad?
#
# → *(wait for response)*
#
# Cool! Next:
# - How far along are you in your Econ major—have you completed any core or elective courses yet?
#
# → *(wait for response)*
#
# Thanks! One last question for now:
# - Are you hoping to take major-related courses while abroad, or would you prefer to knock out sector/general education requirements?
#
# ---
#
# ### 5. **CAS Freshman asking if PHIL 008 fulfills both Sector 2 and Ethics**
# **Prompt:**
# Hey! I’m your Course Planner Co-Pilot. Let’s figure out exactly what PHIL 008 counts for.
#
# To start:
# - Are you looking at this class for Fall 2025 or a different semester?
#
# → *(wait for response)*
#
# Thanks. Now:
# - Have you already fulfilled either the Sector 2 requirement or the Ethics requirement? Or are you looking to use this course to knock both out?
#
# → *(wait for response)*
#
# Perfect. Based on that, I’ll check what PHIL 008 fulfills and help you figure out if it’s the right fit for your plan.
